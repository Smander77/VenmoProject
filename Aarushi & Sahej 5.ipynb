# %%
#Review

#Write a for loop, while loop, and if/elif/else statement with multiple conditions (if a and b, a or b)

#for loop: iterate through a list and print every number in list

bobsburgers = [1,2,3,4,5,6]

#for someRandomVariableName in myListName

for booger in bobsburgers:
  print(booger)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6

# %%
#while loop

storeCount = 0

while storeCount < 20:
  print("Come inside the store as current store Count is: ", storeCount)
  storeCount += 1
# Out:
# Come inside the store as current store Count is:  0
# Come inside the store as current store Count is:  1
# Come inside the store as current store Count is:  2
# Come inside the store as current store Count is:  3
# Come inside the store as current store Count is:  4
# Come inside the store as current store Count is:  5
# Come inside the store as current store Count is:  6
# Come inside the store as current store Count is:  7
# Come inside the store as current store Count is:  8
# Come inside the store as current store Count is:  9
# Come inside the store as current store Count is:  10
# Come inside the store as current store Count is:  11
# Come inside the store as current store Count is:  12
# Come inside the store as current store Count is:  13
# Come inside the store as current store Count is:  14
# Come inside the store as current store Count is:  15
# Come inside the store as current store Count is:  16
# Come inside the store as current store Count is:  17
# ...

# %%
sleepy= False
full = True

#AND statements, OR statements
if sleepy and full:
  print("Go to sleep!")
elif sleepy:
  print("Take a nap!")
elif full:
  print("Go to the bathroom!")
else:
  print("I'm Nothing!")
# Out:
# Go to the bathroom!

# %%
#FUNCTIONS

#Preset instructions


#Dictionary -> defn for words

#Function = definition

#Preset instructions for adding two numbers
'''
def functionName(inputs):
  what does my function do
'''

def addNum(x,y):
  #print(x+y)
  return (x + y)

bob = addNum(546,4564)
print(bob)


#Make a function where u give 3 inputs and it returns a list of those 3 inputs (do makeList(1,2,3) -> [1,2,3])
# Out:
# 5110

# %%
def listMaker(x,y,z):
  return [x,y,z]

bob= listMaker(1,2,5)
print(bob)
# Out:
# [1, 2, 5]

# %%
def divideAarushi(a,b):
  #Z = listMaker(1,224234,3234234) FUNCTION IN A FUNCTION NEXT TIME
  #Try catch gives it permission to fail without having code combust
  try:
    return a/b
  except ZeroDivisionError:
    print("u cannot divide by 0")
  except TypeError:
    print("u need to have two numbers")

print(divideAarushi('billy','bob'))
# Out:
# u need to have two numbers
# None

# %%
#Function Swagg to do before next class

#Make a function that takes in a string (that are your names) and then prints out the length of the string (hint use the len() function)

#Make a function that has takes in two people's balances and the amount to add to their balances, and then just updates balance, NO RETURNING

#Make a try, catch example that is different....maybe some other math thing or find something online and try implementing
